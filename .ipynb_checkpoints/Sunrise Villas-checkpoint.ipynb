# %% [markdown]
# ### Inport Libraries

# %%
import os

# %% [markdown]
# ---

# %% [markdown]
# ### Main Program

# %%
img_path ='../SUNRISE-VILLAS-MYKONOS/Sunrise_Villas_V/'
webp_files = [f for f in os.listdir(path=img_path) if f.lower().endswith('.webp')]

img_len = len(webp_files)

# %%
webp_files
# Out:
# ['1.webp',
#  '10.webp',
#  '11.webp',
#  '12.webp',
#  '13.webp',
#  '14.webp',
#  '15.webp',
#  '16.webp',
#  '17.webp',
#  '18.webp',
#  '18_1.webp',
#  '2.webp',
#  '20.webp',
#  '20_a.webp',
#  '22.webp',
#  '23.webp',
#  '23_a.webp',
#  '24.webp',
#  '26.webp',
#  '27.webp',
#  '28.webp',
#  '29.webp',
#  '30.webp',
#  '32.webp',
#  '4.webp',
#  '5.webp',
#  '6.webp',
#  '7.webp',
#  '8.webp',
#  '9.webp']

# %%
img_len
# Out:
# 30

# %%
webp_files[4]
# Out:
# '13.webp'
